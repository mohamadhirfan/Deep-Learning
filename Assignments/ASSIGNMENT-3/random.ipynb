# %% [markdown]
# <div style="color:white;background-color:black;border:5px solid powderblue;border-radius:25px;text-align:center;font-family:Copperplate">
#     <h1>DATA DECISION PATHS</h1><hr style="border:2px solid powderblue">
#     <div style="color:white;background-color:black;border-radius:25px;text-align:right;">
#         <br>
#         <h2 style="color:red;display:inline;">NAME:</h2><h2 style="display:inline;">Mohamadh Irfan</h2><br>
#         <h2 style="color:red;display:inline;">BATCH:</h2><h2 style="display:inline;padding-right:62px;">AI-ELITE-7</h2>
#     </div>
#     <div style="color:white;background-color:black;border-radius:25px;text-align:Left;font-family:Courier New;margin-left:4%;">
#         <h3 style="color:white;font-weight:bold;font-family:Papyrus">Data Description:</h3>
#         <p style="padding-left:8%;padding-right:8%;">
#         - The dataset consists of three columns and 400 rows which includes two feature columns and one label column.<br>
#         - Features columns are in the form of float and continuous values ranges from <strong>[-0.206000 to 1.100000	]</strong> and <strong>[0.094500 to 1.240000 ]</strong> and the means are at <strong>[0.473766 and	0.678849]</strong>.<br>
#          - Whereas label is in the form discreate numerical integer values that inclueds <strong>[0 and 1]</strong>. 50% of the data consists of 0 and rest consists of 1 as labels.<br>
#             - There are zero duplicates and no null values consists in the dataset.<br>
#             <strong>-</strong> Pattern that is formed by the input features is <strong>Ranndom shape</strong>. That means adatapoints are randomly distributed
#             <img src=https://cdn.discordapp.com/attachments/1060498631981023282/1109937822288318604/image.png
#                  >
#         </p>
#         <br>
#     </div>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"9.random.csv",header=None)

# %%
df.head()
# Out:
#        0      1    2
# 0  0.374  1.080  0.0
# 1  0.445  1.140  1.0
# 2  0.514  1.130  0.0
# 3  0.466  1.240  1.0
# 4  0.371  0.968  1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       400 non-null    float64
#  1   1       400 non-null    float64
#  2   2       400 non-null    float64
# dtypes: float64(3)
# memory usage: 9.5 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# 0    0
# 1    0
# 2    0
# dtype: int64

# %%
df.describe()
# Out:
#                 0           1           2
# count  400.000000  400.000000  400.000000
# mean     0.473766    0.678849    0.505000
# std      0.303491    0.277019    0.500601
# min     -0.206000    0.094500    0.000000
# 25%      0.247000    0.429750    0.000000
# 50%      0.488000    0.692500    1.000000
# 75%      0.726500    0.922250    1.000000
# max      1.100000    1.240000    1.000000

# %%
df[2].value_counts()
# Out:
# 1.0    202
# 0.0    198
# Name: 2, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[[0,1]],df[2],test_size=0.2,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((320, 2), (80, 2))

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_trains = scale.fit_transform(X_train)
X_tests = scale.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LayerNormalization

# %%
model = Sequential()
model.add(Dense(18,activation="relu",kernel_initializer="he_normal",input_dim=2))

model.add(Dense(17,activation="relu",kernel_initializer="he_normal"))
model.add(Dense(16,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(15,activation="relu",kernel_initializer="he_normal"))
model.add(Dense(14,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(13,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(12,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(11,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(10,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(9,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(8,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(6,activation="relu",kernel_initializer="he_normal"))


model.add(Dense(5,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(4,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(2,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(1,activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_509 (Dense)           (None, 18)                54
#
#  dense_510 (Dense)           (None, 17)                323
#
#  dense_511 (Dense)           (None, 16)                288
#
#  dense_512 (Dense)           (None, 15)                255
#
#  dense_513 (Dense)           (None, 14)                224
#
#  dense_514 (Dense)           (None, 13)                195
#
#  dense_515 (Dense)           (None, 12)                168
#
#  dense_516 (Dense)           (None, 11)                143
#
#  dense_517 (Dense)           (None, 10)                120
#
#  dense_518 (Dense)           (None, 9)                 99
#
#  dense_519 (Dense)           (None, 8)                 80
#
#  dense_520 (Dense)           (None, 6)                 54
#
#  dense_521 (Dense)           (None, 5)                 35
#
#  dense_522 (Dense)           (None, 4)                 24
#
#  dense_523 (Dense)           (None, 2)                 10
#
#  dense_524 (Dense)           (None, 1)                 3
#
# =================================================================
# Total params: 2,075
# Trainable params: 2,075
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
history = model.fit(X_trains,y_train,epochs=70,batch_size=10,validation_split=0.1)
# Out:
# Epoch 1/70
# 29/29 [==============================] - 3s 14ms/step - loss: 0.6953 - accuracy: 0.5035 - val_loss: 0.6902 - val_accuracy: 0.5938
# Epoch 2/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6940 - accuracy: 0.4653 - val_loss: 0.6929 - val_accuracy: 0.4688
# Epoch 3/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6933 - val_accuracy: 0.4375
# Epoch 4/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6943 - accuracy: 0.4931 - val_loss: 0.6924 - val_accuracy: 0.5000
# Epoch 5/70
# 29/29 [==============================] - 0s 7ms/step - loss: 0.6939 - accuracy: 0.4792 - val_loss: 0.6937 - val_accuracy: 0.4062
# Epoch 6/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.4757 - val_loss: 0.6930 - val_accuracy: 0.5938
# Epoch 7/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6931 - val_accuracy: 0.5938
# Epoch 8/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6933 - accuracy: 0.4201 - val_loss: 0.6929 - val_accuracy: 0.5938
# Epoch 9/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.4688 - val_loss: 0.6930 - val_accuracy: 0.5938
# Epoch 10/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6929 - val_accuracy: 0.5938
# Epoch 11/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6927 - val_accuracy: 0.5938
# Epoch 12/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6925 - val_accuracy: 0.5938
# Epoch 13/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6928 - val_accuracy: 0.5938
# Epoch 14/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6926 - val_accuracy: 0.5938
# Epoch 15/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6926 - val_accuracy: 0.5938
# Epoch 16/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6925 - val_accuracy: 0.5938
# Epoch 17/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6926 - val_accuracy: 0.5938
# Epoch 18/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6926 - val_accuracy: 0.5938
# Epoch 19/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6925 - val_accuracy: 0.5938
# Epoch 20/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6923 - val_accuracy: 0.5938
# Epoch 21/70
# 29/29 [==============================] - 0s 7ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6925 - val_accuracy: 0.5938
# Epoch 22/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6924 - val_accuracy: 0.5938
# Epoch 23/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6923 - val_accuracy: 0.5938
# Epoch 24/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6925 - val_accuracy: 0.5938
# Epoch 25/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6924 - val_accuracy: 0.5938
# Epoch 26/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6923 - val_accuracy: 0.5938
# Epoch 27/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6923 - val_accuracy: 0.5938
# Epoch 28/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6923 - val_accuracy: 0.5938
# Epoch 29/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6923 - val_accuracy: 0.5938
# Epoch 30/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6922 - val_accuracy: 0.5938
# Epoch 31/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 32/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6922 - val_accuracy: 0.5938
# Epoch 33/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6922 - val_accuracy: 0.5938
# Epoch 34/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 35/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 36/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 37/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 38/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 39/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 40/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 41/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 42/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6920 - val_accuracy: 0.5938
# Epoch 43/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6922 - val_accuracy: 0.5938
# Epoch 44/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6918 - val_accuracy: 0.5938
# Epoch 45/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 46/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6922 - val_accuracy: 0.5938
# Epoch 47/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6920 - val_accuracy: 0.5938
# Epoch 48/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 49/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6933 - accuracy: 0.5035 - val_loss: 0.6922 - val_accuracy: 0.5938
# Epoch 50/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 51/70
# 29/29 [==============================] - 0s 7ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 52/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6920 - val_accuracy: 0.5938
# Epoch 53/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 54/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6921 - val_accuracy: 0.5938
# Epoch 55/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 56/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6933 - accuracy: 0.5035 - val_loss: 0.6922 - val_accuracy: 0.5938
# Epoch 57/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 58/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6918 - val_accuracy: 0.5938
# Epoch 59/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6920 - val_accuracy: 0.5938
# Epoch 60/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6918 - val_accuracy: 0.5938
# Epoch 61/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 62/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6916 - val_accuracy: 0.5938
# Epoch 63/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 64/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6920 - val_accuracy: 0.5938
# Epoch 65/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6917 - val_accuracy: 0.5938
# Epoch 66/70
# 29/29 [==============================] - 0s 6ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6917 - val_accuracy: 0.5938
# Epoch 67/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 68/70
# 29/29 [==============================] - 0s 5ms/step - loss: 0.6932 - accuracy: 0.5035 - val_loss: 0.6917 - val_accuracy: 0.5938
# Epoch 69/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6919 - val_accuracy: 0.5938
# Epoch 70/70
# 29/29 [==============================] - 0s 4ms/step - loss: 0.6931 - accuracy: 0.5035 - val_loss: 0.6920 - val_accuracy: 0.5938

# %%
y_cap=model.predict(X_tests)
# Out:
# 3/3 [==============================] - 0s 2ms/step

# %%
y_capf=np.where(y_cap>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_capf)
# Out:
# 0.475

# %%
data = np.array([history.history["loss"],history.history["val_loss"]])
# data = data.reshape(50,2)
[[data[:,0].max(),data[:,1].max()]]
# Out:
# [[0.6948666572570801, 0.6929110884666443]]

# %%
plt.figure(figsize=(8,6),dpi=150)
plt.plot(history.history["loss"],'black',linewidth=5)
plt.plot(history.history["val_loss"],'r',linewidth=5)
plt.plot(history.history["accuracy"],"blue")
plt.table(cellText=[[data[:,0].max(),data[:,1].max()],["Min Train Loss","Min Validation Loss"],[data[:,0].min(),data[:,1].min()]],cellLoc='center',colWidths=[0.4,0.4,0.4],
         colLabels=['Max Train Loss','Max Validation Loss'],colColours=['pink','yellow'],bbox=[0,0,1,1])
plt.legend(["Loss","Val_Loss","accuracy"])
plt.title("Train Loss and Validation Loss",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("Number of Epochs",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("Loss",color='red',fontsize='medium',fontfamily='serif')
plt.show()

# %%
from mlxtend.plotting import plot_decision_regions as pt

# %%
plt.figure(figsize=(8,6),dpi=150)
pt(X_trains,y_train.values.astype(int),clf=model)
plt.title("X_train Decision regions",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("X_train",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("y_train",color='red',fontsize='medium',fontfamily='serif')
plt.show()
# Out:
# 9600/9600 [==============================] - 12s 1ms/step

# %%
y_pred = model.predict(X_tests)
# Out:
# 3/3 [==============================] - 0s 3ms/step

# %%
y_predf = np.array([1 if x>0.5 else 0 for x in y_pred])

# %%
plt.figure(figsize=(8,6),dpi=150)
pt(X_tests,y_predf.astype(int),clf=model)
plt.title("X_test Decision regions",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("X_test",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("y_test",color='red',fontsize='medium',fontfamily='serif')
plt.show()
# Out:
# 33750/33750 [==============================] - 45s 1ms/step
