# %% [markdown]
# <div style="color:white;background-color:black;border:5px solid powderblue;border-radius:25px;text-align:center;font-family:Copperplate">
#     <h1>DATA DECISION PATHS</h1><hr style="border:2px solid powderblue">
#     <div style="color:white;background-color:black;border-radius:25px;text-align:right;">
#         <br>
#         <h2 style="color:red;display:inline;">NAME:</h2><h2 style="display:inline;">Mohamadh Irfan</h2><br>
#         <h2 style="color:red;display:inline;">BATCH:</h2><h2 style="display:inline;padding-right:62px;">AI-ELITE-7</h2>
#     </div>
#     <div style="color:white;background-color:black;border-radius:25px;text-align:Left;font-family:Courier New;margin-left:4%;">
#         <h3 style="color:white;font-weight:bold;font-family:Papyrus">Data Description:</h3>
#         <p style="padding-left:8%;padding-right:8%;">
#         - The dataset consists of three columns and 100 rows which includes two feature columns and one label column.<br>
#         - Features columns are in the form of float and continuous values ranges from <strong>[-3.950019 to 6.712027			]</strong> and <strong>[-3.935098 to 7.848278 ]</strong> and the means are at <strong>[1.883707	and 1.869874	]</strong>.<br>
#          - Whereas label is in the form discreate numerical integer values that inclueds <strong>[0 and 1]</strong>. 50% of the data consists of 0 and rest consists of 1 as labels.<br>
#             - There are zero duplicates and no null values consists in the dataset.<br>
#             <strong>-</strong> Pattern that is formed by the input features is <strong>concerticcir-2 shape</strong>. The dataset consists of two concentric circled data points. One concentred the other labelled datapoints.
#             <img src=https://cdn.discordapp.com/attachments/1060498631981023282/1109938013397602344/image.png
#                  >
#         </p>
#         <br>
#     </div>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("3.concertriccir2.csv",header=None)

# %%
df.head()
# Out:
#           0         1    2
# 0  0.700335 -0.247068  0.0
# 1 -3.950019  2.740080  1.0
# 2  0.150222 -2.157638  1.0
# 3 -1.672050 -0.941519  1.0
# 4  2.560483 -1.846577  1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       500 non-null    float64
#  1   1       500 non-null    float64
#  2   2       500 non-null    float64
# dtypes: float64(3)
# memory usage: 11.8 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# 0    0
# 1    0
# 2    0
# dtype: int64

# %%
num=df.select_dtypes(include='number')

# %%
for i in num:
    sns.boxplot(num[i])
    plt.show()

# %%
df.describe()
# Out:
#                 0           1           2
# count  500.000000  500.000000  500.000000
# mean     1.883707    1.869874    0.500000
# std      1.931275    1.986852    0.500501
# min     -3.950019   -3.935098    0.000000
# 25%      0.403585    0.426457    0.000000
# 50%      2.191547    2.109658    0.500000
# 75%      3.349001    3.388552    1.000000
# max      6.712027    7.848278    1.000000

# %%
df[2].value_counts()
# Out:
# 0.0    250
# 1.0    250
# Name: 2, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[[0,1]],df[2],test_size=0.2,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((400, 2), (100, 2))

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_trains = scale.fit_transform(X_train)
X_tests = scale.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
model = Sequential()
model.add(Dense(14,activation="relu",kernel_initializer="he_normal",input_dim=2))

model.add(Dense(9,activation="relu",kernel_initializer="he_normal"))



model.add(Dense(8,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(7,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(6,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(5,activation="relu",kernel_initializer="he_normal"))


model.add(Dense(4,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(4,activation="relu",kernel_initializer="he_normal"))

model.add(Dense(2,activation="relu",kernel_initializer="he_normal"))
model.add(Dropout(0.3))
model.add(Dense(1,activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_67"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_787 (Dense)           (None, 14)                42
#
#  dense_788 (Dense)           (None, 9)                 135
#
#  dense_789 (Dense)           (None, 8)                 80
#
#  dense_790 (Dense)           (None, 7)                 63
#
#  dense_791 (Dense)           (None, 6)                 48
#
#  dense_792 (Dense)           (None, 5)                 35
#
#  dense_793 (Dense)           (None, 4)                 24
#
#  dense_794 (Dense)           (None, 4)                 20
#
#  dense_795 (Dense)           (None, 2)                 10
#
#  dropout_152 (Dropout)       (None, 2)                 0
#
#  dense_796 (Dense)           (None, 1)                 3
#
# =================================================================
# Total params: 460
# Trainable params: 460
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
history = model.fit(X_trains,y_train,epochs=40,batch_size=12,validation_split=0.2)
# Out:
# Epoch 1/40
# 27/27 [==============================] - 2s 11ms/step - loss: 1.6907 - accuracy: 0.5094 - val_loss: 1.0849 - val_accuracy: 0.4625
# Epoch 2/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.8885 - accuracy: 0.4812 - val_loss: 0.7596 - val_accuracy: 0.3750
# Epoch 3/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7653 - accuracy: 0.4250 - val_loss: 0.7033 - val_accuracy: 0.3750
# Epoch 4/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.7195 - accuracy: 0.4125 - val_loss: 0.6823 - val_accuracy: 0.4500
# Epoch 5/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6933 - accuracy: 0.4719 - val_loss: 0.6641 - val_accuracy: 0.6000
# Epoch 6/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6836 - accuracy: 0.5156 - val_loss: 0.6611 - val_accuracy: 0.6125
# Epoch 7/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6801 - accuracy: 0.5063 - val_loss: 0.6584 - val_accuracy: 0.6125
# Epoch 8/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6810 - accuracy: 0.5063 - val_loss: 0.6569 - val_accuracy: 0.6125
# Epoch 9/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6885 - accuracy: 0.4844 - val_loss: 0.6580 - val_accuracy: 0.6125
# Epoch 10/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6778 - accuracy: 0.5094 - val_loss: 0.6547 - val_accuracy: 0.6125
# Epoch 11/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6707 - accuracy: 0.5156 - val_loss: 0.6557 - val_accuracy: 0.5625
# Epoch 12/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6781 - accuracy: 0.5031 - val_loss: 0.6534 - val_accuracy: 0.5750
# Epoch 13/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6720 - accuracy: 0.5063 - val_loss: 0.6509 - val_accuracy: 0.6125
# Epoch 14/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6765 - accuracy: 0.5000 - val_loss: 0.6481 - val_accuracy: 0.6125
# Epoch 15/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6691 - accuracy: 0.5250 - val_loss: 0.6464 - val_accuracy: 0.6125
# Epoch 16/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6609 - accuracy: 0.5188 - val_loss: 0.6461 - val_accuracy: 0.6125
# Epoch 17/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6713 - accuracy: 0.4938 - val_loss: 0.6418 - val_accuracy: 0.6125
# Epoch 18/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6624 - accuracy: 0.5156 - val_loss: 0.6407 - val_accuracy: 0.6125
# Epoch 19/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6577 - accuracy: 0.5281 - val_loss: 0.6375 - val_accuracy: 0.5875
# Epoch 20/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6482 - accuracy: 0.5469 - val_loss: 0.6368 - val_accuracy: 0.6125
# Epoch 21/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6551 - accuracy: 0.5719 - val_loss: 0.6367 - val_accuracy: 0.6125
# Epoch 22/40
# 27/27 [==============================] - 0s 7ms/step - loss: 0.6561 - accuracy: 0.5906 - val_loss: 0.6339 - val_accuracy: 0.7250
# Epoch 23/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6407 - accuracy: 0.6094 - val_loss: 0.6324 - val_accuracy: 0.7875
# Epoch 24/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6355 - accuracy: 0.6406 - val_loss: 0.6295 - val_accuracy: 0.7125
# Epoch 25/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6429 - accuracy: 0.6844 - val_loss: 0.6283 - val_accuracy: 0.7625
# Epoch 26/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6382 - accuracy: 0.6531 - val_loss: 0.6248 - val_accuracy: 0.7625
# Epoch 27/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6474 - accuracy: 0.6625 - val_loss: 0.6215 - val_accuracy: 0.7250
# Epoch 28/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6393 - accuracy: 0.6031 - val_loss: 0.6224 - val_accuracy: 0.8000
# Epoch 29/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6236 - accuracy: 0.7312 - val_loss: 0.6181 - val_accuracy: 0.7125
# Epoch 30/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6231 - accuracy: 0.6687 - val_loss: 0.6138 - val_accuracy: 0.8125
# Epoch 31/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6448 - accuracy: 0.6438 - val_loss: 0.6102 - val_accuracy: 0.7750
# Epoch 32/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6053 - accuracy: 0.7156 - val_loss: 0.6058 - val_accuracy: 0.7625
# Epoch 33/40
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6126 - accuracy: 0.6781 - val_loss: 0.6053 - val_accuracy: 0.7625
# Epoch 34/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6298 - accuracy: 0.6531 - val_loss: 0.6033 - val_accuracy: 0.7875
# Epoch 35/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6044 - accuracy: 0.7250 - val_loss: 0.5961 - val_accuracy: 0.7875
# Epoch 36/40
# 27/27 [==============================] - 0s 6ms/step - loss: 0.6190 - accuracy: 0.6656 - val_loss: 0.5990 - val_accuracy: 0.8500
# Epoch 37/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6224 - accuracy: 0.6625 - val_loss: 0.5840 - val_accuracy: 0.8000
# Epoch 38/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6158 - accuracy: 0.7063 - val_loss: 0.5882 - val_accuracy: 0.7375
# Epoch 39/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.6084 - accuracy: 0.6938 - val_loss: 0.5792 - val_accuracy: 0.8250
# Epoch 40/40
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5927 - accuracy: 0.7188 - val_loss: 0.5714 - val_accuracy: 0.8375

# %%
model.get_weights()
# Out:
# [array([[-0.10863682,  0.54760236,  0.34448698,  1.040546  , -0.9193524 ,
#          -1.2057132 , -0.21120912, -1.5537717 ,  0.4921038 , -1.6247201 ,
#          -0.5767908 , -0.4295047 ,  1.637869  , -0.14622158],
#         [ 0.27580234, -1.7235328 , -0.00782966, -0.35618797, -1.0282648 ,
#           0.6366419 , -1.4198127 ,  0.32513413,  0.0566269 , -1.8218522 ,
#          -1.3994083 , -0.16749385, -0.62184614,  1.866805  ]],
#        dtype=float32),
#  array([ 0.06402625, -0.05078274, -0.06960586,  0.00578073,  0.0062388 ,
#         -0.03686908,  0.05372395,  0.09928346, -0.05006293, -0.04236912,
#          0.06595273, -0.00549017, -0.03783176, -0.12324566], dtype=float32),
#  array([[-0.7343507 ,  0.18654168, -0.34515074,  0.44277385, -0.7094488 ,
#          -0.24050474, -0.25851622,  0.24388734,  0.32271335],
#         [-0.1312264 , -0.30194715, -0.20775689,  0.15665613,  0.39039773,
#          -0.7661936 , -0.78303826,  0.25106826, -0.48462206],
#         [ 0.20028898, -0.31901205, -0.5929714 , -0.07882766, -0.2015188 ,
#          -0.49541315,  0.5496673 , -0.10322051,  0.48899895],
#         [ 0.3719329 ,  0.54870194, -0.68374085, -0.683696  , -0.2980932 ,
#          -0.02384735, -0.68467134, -0.02487809, -0.02838471],
#         [-0.26239103,  0.15624872,  0.1473828 ,  0.25261337, -0.16418779,
#           0.05127547,  0.06083633,  0.07859617,  0.17436042],
#         [-0.69688284,  0.11873183, -0.14590196,  0.7935917 ,  0.39591452,
#           0.9865442 , -0.6028977 ,  0.5516588 , -0.39555126],
#         [ 0.56291676, -0.22184134, -0.16589436, -0.6681844 ,  0.16181336,
#          -0.22873388, -0.01989883, -0.05657006,  0.14930138],
#         [-0.5801103 ,  0.03352118,  0.5615389 , -0.19897626, -0.36678645,
#          -0.66568696,  0.50806975, -0.19506408,  0.8347868 ],
#         [-0.0261362 ,  0.8515234 , -0.1069508 ,  0.11485368,  0.4767426 ,
#           0.27346623,  0.48481604,  0.17290632, -0.13190293],
#         [ 0.4071506 ,  0.25994667, -0.23044236,  0.03788751, -0.22510777,
#           0.2363113 , -0.31267944,  0.67937046, -0.14066666],
#         [ 0.2621861 , -0.5193183 ,  0.3095064 , -0.11787125,  0.25687966,
#          -0.06420441, -0.36961195, -0.16125984,  0.39718232],
#         [ 0.19299968,  0.163011  , -0.5409928 ,  0.37677822,  0.24782082,
#           0.00264592,  0.3620197 ,  0.27366802,  0.06577386],
#         [ 0.556956  , -0.00512281,  0.3790601 ,  0.53339666, -0.00198261,
#           0.01669134, -0.2056253 ,  0.38879552,  0.08703176],
#         [ 0.7229728 ,  0.57764316, -0.21203037, -0.2091693 , -0.1422191 ,
#           0.35631928,  0.08038639,  0.09044544, -0.14335273]],
#        dtype=float32),
#  array([-0.12608996,  0.01701992, -0.03320579, -0.0281303 ,  0.02496912,
#         -0.10904642, -0.0936787 , -0.01777523,  0.05258549], dtype=float32),
#  array([[ 0.46397966, -0.1731961 , -0.17703305, -0.15523253, -0.9644984 ,
#           0.18163127,  0.07272941,  0.42495397],
#         [ 0.2048436 , -0.7443509 ,  0.09963265, -0.47492397,  0.6385766 ,
#           0.24120437, -0.58820087,  0.38972366],
#         [-0.32516196, -0.14064328, -0.4549947 ,  0.51374614,  0.05156649,
#          -0.01653042,  0.2863735 , -1.0968221 ],
#         [ 0.6893719 , -0.26087764, -0.07335251,  0.49702412,  0.2534563 ,
#          -0.7400635 ,  0.48936164, -1.0495874 ],
#         [ 0.2776991 ,  0.39659664, -0.4965462 , -0.01073353,  1.0240093 ,
#          -0.21589118,  0.13573682,  0.5565664 ],
#         [ 0.76030135,  0.98717153, -0.43215415, -0.03972003, -0.85339624,
#           0.3546807 , -0.64646447,  0.72183573],
#         [-0.02362771, -0.41097498, -0.9611867 ,  0.9776953 , -0.32521725,
#          -0.50942695,  0.18400577, -0.36032572],
#         [ 0.38060328,  0.2595831 , -0.26633596, -0.36132836, -0.3263267 ,
#           0.5372364 ,  0.5132234 ,  0.69634444],
#         [ 0.3065452 ,  0.11878033, -0.15705691, -0.12586254, -0.7931994 ,
#          -0.44794738, -1.1545119 ,  0.03821296]], dtype=float32),
#  array([-0.05444493, -0.058726  ,  0.        ,  0.        , -0.02537262,
#          0.09899221, -0.02465084, -0.08667593], dtype=float32),
#  array([[ 0.0043093 , -0.704677  ,  0.64574194,  0.73805344, -0.2723455 ,
#           0.36456883,  0.999264  ],
#         [ 0.28439778, -0.1856486 ,  0.84671134, -0.3101614 , -0.45082048,
#           0.9478473 , -0.5402844 ],
#         [-1.0734559 ,  0.0716344 ,  0.07427021, -0.44863987, -0.61728114,
#           0.11680612, -0.05133111],
#         [ 0.6417312 , -0.30193403,  0.26720345, -0.1474775 ,  0.01690429,
#          -0.6941281 , -0.0616386 ],
#         [ 0.2183402 , -0.6485411 ,  0.8698532 , -0.30766308,  0.11705505,
#           0.84028834, -0.22729318],
#         [-0.33303028, -0.22267237,  0.9007477 , -0.2761936 ,  0.1620641 ,
#           0.3289919 ,  0.56168264],
#         [-0.046238  , -0.83923596,  0.62546474, -0.7270237 ,  0.89994633,
#           0.23445606, -0.6156863 ],
#         [ 0.26362908, -0.8470351 , -0.01450271,  0.04653427, -0.06169565,
#          -0.5337792 ,  0.08358352]], dtype=float32),
#  array([-0.0361382 ,  0.        ,  0.00498668, -0.08431398, -0.02014671,
#         -0.00685368,  0.08272191], dtype=float32),
#  array([[-0.06723479, -0.35899958,  0.23218326,  0.79814535, -0.7377077 ,
#          -0.48692653],
#         [-0.84964675,  0.6930059 , -0.78802395,  0.4699868 , -0.80732894,
#           0.3663015 ],
#         [ 0.04524   ,  0.2727869 , -0.12067879,  0.2130731 , -0.5840587 ,
#          -0.0212523 ],
#         [-1.1484499 , -0.56391215,  1.124576  , -0.4404796 ,  0.05148251,
#          -0.35329425],
#         [ 1.1389457 ,  0.01302682,  0.9820012 ,  0.7356108 , -0.06371038,
#          -0.16441438],
#         [ 0.14752667, -0.16753271,  0.42252776, -0.01953884,  0.87610674,
#           0.188166  ],
#         [ 0.2395586 , -0.82426137, -0.12773097, -0.05696577, -0.1457791 ,
#          -1.0690011 ]], dtype=float32),
#  array([-0.0051911 ,  0.02348167, -0.07275601, -0.0200523 ,  0.        ,
#          0.        ], dtype=float32),
#  array([[ 0.586987  ,  0.03542139,  0.18328673,  0.2418975 , -0.84679294],
#         [-0.8921321 , -0.10286491, -0.07185197, -0.02353749,  0.21076146],
#         [-0.03708279,  0.62758756,  0.08941635,  0.41973925, -0.24911308],
#         [-0.26242247,  0.4406136 ,  0.48213473,  0.47939995,  0.21299633],
#         [-0.25205064, -0.00890536, -0.47640613, -0.33451527,  0.19506279],
#         [ 0.49045733,  0.03825215,  0.91048545, -0.23657647, -0.452328  ]],
#        dtype=float32),
#  array([ 0.00301296, -0.03316917,  0.04146893, -0.07378267, -0.04621867],
#        dtype=float32),
#  array([[ 3.9875320e-01,  7.3149651e-01,  5.0708141e-02,  2.8858057e-01],
#         [-2.1949640e-05,  5.6040269e-01,  1.6400684e-01, -1.2343986e+00],
#         [-7.6587778e-01,  3.1277123e-01, -4.6835139e-01,  5.0460535e-01],
#         [-6.5548736e-01,  7.8299296e-01,  3.2307360e-01,  7.6650983e-01],
#         [ 6.6707003e-01, -3.9410728e-01,  2.9793915e-01,  1.2456404e+00]],
#        dtype=float32),
#  array([ 0.        , -0.06936406, -0.08756988, -0.04848231], dtype=float32),
#  array([[-0.2750207 , -0.4586566 , -0.13674685, -0.7230299 ],
#         [-0.6762373 , -1.0187588 ,  0.9495495 ,  0.6639558 ],
#         [ 0.18723454,  0.4312576 ,  0.25888386,  1.1152695 ],
#         [-0.64280856,  1.2764918 , -0.13137327,  1.2995789 ]],
#        dtype=float32),
#  array([ 0.        ,  0.21186247,  0.03361985, -0.26256135], dtype=float32),
#  array([[ 1.2218976 ,  1.4550198 ],
#         [-0.04225832, -0.8464658 ],
#         [ 0.58253294,  0.67558783],
#         [ 1.0014704 , -0.88565   ]], dtype=float32),
#  array([-0.2955208 ,  0.14880517], dtype=float32),
#  array([[ 0.9700451],
#         [-1.6705201]], dtype=float32),
#  array([0.06420193], dtype=float32)]

# %%
y_cap=model.predict(X_tests)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
y_capf=np.where(y_cap>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_capf)
# Out:
# 0.81

# %%
data = np.array([history.history["loss"],history.history["val_loss"]])
# data = data.reshape(50,2)
[[data[:,0].max(),data[:,1].max()]]
# Out:
# [[1.6906553506851196, 0.888532817363739]]

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.show()

# %%
plt.figure(figsize=(8,6),dpi=150)
plt.plot(history.history["loss"],'black',linewidth=5)
plt.plot(history.history["val_loss"],'r--',linewidth=5)
plt.table(cellText=[[data[:,0].max(),data[:,1].max()],["Min Train Loss","Min Validation Loss"],[data[:,0].min(),data[:,1].min()]],cellLoc='center',colWidths=[0.4,0.4,0.4],
         colLabels=['Max Train Loss','Max Validation Loss'],colColours=['pink','yellow'],bbox=[0,0,1,1])
plt.legend(["Loss","Val_Loss"])
plt.title("Train Loss and Validation Loss",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("Number of Epochs",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("Loss",color='red',fontsize='medium',fontfamily='serif')
plt.show()

# %%
from mlxtend.plotting import plot_decision_regions as pt

plt.figure(figsize=(8,6))
pt(X_trains,y_train.values.astype(int),clf=model)
plt.title("X_train Decision regions",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("X_train",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("y_train",color='red',fontsize='medium',fontfamily='serif')
plt.show()
# Out:
# 15000/15000 [==============================] - 19s 1ms/step

# %%
y_pred = model.predict(X_tests)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
y_predf = np.array([1 if x>0.5 else 0 for x in y_pred])

# %%
plt.figure(figsize=(8,6))
pt(X_tests,y_predf.astype(int),clf=model)
plt.title("X_test Decision regions",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("X_test",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("y_test",color='red',fontsize='medium',fontfamily='serif')
plt.show()
# Out:
# 15000/15000 [==============================] - 17s 1ms/step
