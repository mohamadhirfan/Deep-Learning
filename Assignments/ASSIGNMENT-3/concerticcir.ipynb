# %% [markdown]
# <div style="color:white;background-color:black;border:5px solid powderblue;border-radius:25px;text-align:center;font-family:Copperplate">
#     <h1>DATA DECISION PATHS</h1><hr style="border:2px solid powderblue">
#     <div style="color:white;background-color:black;border-radius:25px;text-align:right;">
#         <br>
#         <h2 style="color:red;display:inline;">NAME:</h2><h2 style="display:inline;">Mohamadh Irfan</h2><br>
#         <h2 style="color:red;display:inline;">BATCH:</h2><h2 style="display:inline;padding-right:62px;">AI-ELITE-7</h2>
#     </div>
#     <div style="color:white;background-color:black;border-radius:25px;text-align:Left;font-family:Courier New;margin-left:4%;">
#         <h3 style="color:white;font-weight:bold;font-family:Papyrus">Data Description:</h3>
#         <p style="padding-left:8%;padding-right:8%;">
#         - The dataset consists of three columns and 100 rows which includes two feature columns and one label column.<br>
#         - Features columns are in the form of float and continuous values ranges from <strong>[-1.131849 to 1.129808	]</strong> and <strong>[-1.289427 to 1.073060 ]</strong> and the means are at <strong>[-0.010872 and -0.019289]</strong>.<br>
#          - Whereas label is in the form discreate numerical integer values that inclueds <strong>[0 and 1]</strong>. 50% of the data consists of 0 and rest consists of 1 as labels.<br>
#             - There are zero duplicates and no null values consists in the dataset.<br>
#             <strong>-</strong> Pattern that is formed by the input features is <strong>concerticcir shape</strong>. The above dataset is in the shape of concentric in which 0 labelled data concentred the 1 labelled datapoints.
#             <img src=https://cdn.discordapp.com/attachments/1060498631981023282/1109938037149929502/image.png
#                  >
#         </p>
#         <br>
#     </div>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("2.concerticcir1.csv",header=None)

# %%
df.head()
# Out:
#           0         1    2
# 0 -0.382891 -0.090840  1.0
# 1 -0.020962 -0.477874  1.0
# 2 -0.396116 -1.289427  0.0
# 3 -0.618130 -0.063837  1.0
# 4  0.703478 -0.187038  1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       100 non-null    float64
#  1   1       100 non-null    float64
#  2   2       100 non-null    float64
# dtypes: float64(3)
# memory usage: 2.5 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# 0    0
# 1    0
# 2    0
# dtype: int64

# %%
num=df.select_dtypes(include='number')

# %%
for i in num:
    sns.boxplot(num[i])
    plt.show()

# %%
df.describe()
# Out:
#                 0           1           2
# count  100.000000  100.000000  100.000000
# mean    -0.010872   -0.019289    0.500000
# std      0.577796    0.542785    0.502519
# min     -1.131849   -1.289427    0.000000
# 25%     -0.450428   -0.433372    0.000000
# 50%     -0.030343   -0.030291    0.500000
# 75%      0.425418    0.420430    1.000000
# max      1.129808    1.073060    1.000000

# %%
df[2].value_counts()
# Out:
# 1.0    50
# 0.0    50
# Name: 2, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[[0,1]],df[2],test_size=0.2,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((80, 2), (20, 2))

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_trains = scale.fit_transform(X_train)
X_tests = scale.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
model = Sequential()
model.add(Dense(9,activation="relu",kernel_initializer="he_uniform",input_dim=2))

model.add(Dense(8,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(7,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(6,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(6,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(5,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(5,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(4,activation="relu",kernel_initializer="he_uniform"))
model.add(Dropout(0.2))
model.add(Dense(2,activation="relu",kernel_initializer="he_uniform"))
model.add(Dropout(0.2))
model.add(Dense(1,activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_389 (Dense)           (None, 9)                 27
#
#  dense_390 (Dense)           (None, 8)                 80
#
#  dense_391 (Dense)           (None, 7)                 63
#
#  dense_392 (Dense)           (None, 6)                 48
#
#  dense_393 (Dense)           (None, 6)                 42
#
#  dense_394 (Dense)           (None, 5)                 35
#
#  dense_395 (Dense)           (None, 5)                 30
#
#  dense_396 (Dense)           (None, 4)                 24
#
#  dropout_118 (Dropout)       (None, 4)                 0
#
#  dense_397 (Dense)           (None, 2)                 10
#
#  dropout_119 (Dropout)       (None, 2)                 0
#
#  dense_398 (Dense)           (None, 1)                 3
#
# =================================================================
# Total params: 362
# Trainable params: 362
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
history = model.fit(X_trains,y_train,epochs=90,batch_size=8,validation_split=0.2)
# Out:
# Epoch 1/90
# 8/8 [==============================] - 2s 39ms/step - loss: 0.6902 - accuracy: 0.4688 - val_loss: 0.6792 - val_accuracy: 0.7500
# Epoch 2/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6871 - accuracy: 0.5312 - val_loss: 0.6744 - val_accuracy: 0.6250
# Epoch 3/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6883 - accuracy: 0.4688 - val_loss: 0.6703 - val_accuracy: 0.6250
# Epoch 4/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6850 - accuracy: 0.4688 - val_loss: 0.6693 - val_accuracy: 0.6250
# Epoch 5/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6845 - accuracy: 0.5156 - val_loss: 0.6668 - val_accuracy: 0.6250
# Epoch 6/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6802 - accuracy: 0.5156 - val_loss: 0.6604 - val_accuracy: 0.6250
# Epoch 7/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6781 - accuracy: 0.5000 - val_loss: 0.6526 - val_accuracy: 0.6250
# Epoch 8/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6774 - accuracy: 0.5156 - val_loss: 0.6440 - val_accuracy: 0.6250
# Epoch 9/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6800 - accuracy: 0.4844 - val_loss: 0.6380 - val_accuracy: 0.6250
# Epoch 10/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6785 - accuracy: 0.4688 - val_loss: 0.6377 - val_accuracy: 0.6875
# Epoch 11/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6705 - accuracy: 0.4688 - val_loss: 0.6332 - val_accuracy: 0.6875
# Epoch 12/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6643 - accuracy: 0.5625 - val_loss: 0.6235 - val_accuracy: 0.6875
# Epoch 13/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.6633 - accuracy: 0.4844 - val_loss: 0.6155 - val_accuracy: 0.6875
# Epoch 14/90
# 8/8 [==============================] - 0s 12ms/step - loss: 0.6764 - accuracy: 0.4375 - val_loss: 0.6061 - val_accuracy: 0.6875
# Epoch 15/90
# 8/8 [==============================] - 0s 11ms/step - loss: 0.6472 - accuracy: 0.5625 - val_loss: 0.5987 - val_accuracy: 0.7500
# Epoch 16/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6484 - accuracy: 0.5938 - val_loss: 0.5828 - val_accuracy: 0.6875
# Epoch 17/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6440 - accuracy: 0.6094 - val_loss: 0.5697 - val_accuracy: 0.6875
# Epoch 18/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6342 - accuracy: 0.5938 - val_loss: 0.5564 - val_accuracy: 0.6875
# Epoch 19/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6595 - accuracy: 0.5781 - val_loss: 0.5574 - val_accuracy: 0.8125
# Epoch 20/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6469 - accuracy: 0.5781 - val_loss: 0.5511 - val_accuracy: 0.8125
# Epoch 21/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6357 - accuracy: 0.5938 - val_loss: 0.5379 - val_accuracy: 0.8125
# Epoch 22/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6523 - accuracy: 0.6250 - val_loss: 0.5427 - val_accuracy: 0.8125
# Epoch 23/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6330 - accuracy: 0.6094 - val_loss: 0.5407 - val_accuracy: 0.8125
# Epoch 24/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6175 - accuracy: 0.7344 - val_loss: 0.5338 - val_accuracy: 0.8125
# Epoch 25/90
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6203 - accuracy: 0.6562 - val_loss: 0.5148 - val_accuracy: 0.8125
# Epoch 26/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5986 - accuracy: 0.6719 - val_loss: 0.5081 - val_accuracy: 0.8125
# Epoch 27/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5959 - accuracy: 0.7344 - val_loss: 0.4943 - val_accuracy: 0.8125
# Epoch 28/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6196 - accuracy: 0.6406 - val_loss: 0.4892 - val_accuracy: 0.8125
# Epoch 29/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5819 - accuracy: 0.7031 - val_loss: 0.4819 - val_accuracy: 0.8125
# Epoch 30/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6337 - accuracy: 0.6094 - val_loss: 0.4889 - val_accuracy: 0.8125
# Epoch 31/90
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5776 - accuracy: 0.6875 - val_loss: 0.4855 - val_accuracy: 0.8125
# Epoch 32/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5866 - accuracy: 0.7031 - val_loss: 0.4779 - val_accuracy: 0.8125
# Epoch 33/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5810 - accuracy: 0.6875 - val_loss: 0.4675 - val_accuracy: 0.8125
# Epoch 34/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5891 - accuracy: 0.6562 - val_loss: 0.4616 - val_accuracy: 0.8125
# Epoch 35/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5412 - accuracy: 0.7656 - val_loss: 0.4578 - val_accuracy: 0.8125
# Epoch 36/90
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5357 - accuracy: 0.7812 - val_loss: 0.4435 - val_accuracy: 0.8125
# Epoch 37/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5491 - accuracy: 0.6875 - val_loss: 0.4409 - val_accuracy: 0.8125
# Epoch 38/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5568 - accuracy: 0.7188 - val_loss: 0.4543 - val_accuracy: 0.8750
# Epoch 39/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5370 - accuracy: 0.7812 - val_loss: 0.4576 - val_accuracy: 0.8750
# Epoch 40/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5733 - accuracy: 0.7500 - val_loss: 0.4467 - val_accuracy: 0.8750
# Epoch 41/90
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5323 - accuracy: 0.8281 - val_loss: 0.4268 - val_accuracy: 0.8750
# Epoch 42/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5241 - accuracy: 0.7656 - val_loss: 0.4218 - val_accuracy: 0.8750
# Epoch 43/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5303 - accuracy: 0.7812 - val_loss: 0.4249 - val_accuracy: 0.8750
# Epoch 44/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5507 - accuracy: 0.8281 - val_loss: 0.4239 - val_accuracy: 0.9375
# Epoch 45/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4912 - accuracy: 0.8438 - val_loss: 0.4068 - val_accuracy: 0.9375
# Epoch 46/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4741 - accuracy: 0.8750 - val_loss: 0.3932 - val_accuracy: 0.8750
# Epoch 47/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5169 - accuracy: 0.8125 - val_loss: 0.4083 - val_accuracy: 0.9375
# Epoch 48/90
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5168 - accuracy: 0.8438 - val_loss: 0.4096 - val_accuracy: 0.9375
# Epoch 49/90
# 8/8 [==============================] - 0s 14ms/step - loss: 0.5076 - accuracy: 0.8281 - val_loss: 0.3836 - val_accuracy: 0.9375
# Epoch 50/90
# 8/8 [==============================] - 0s 12ms/step - loss: 0.4554 - accuracy: 0.9219 - val_loss: 0.3710 - val_accuracy: 0.8750
# Epoch 51/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4928 - accuracy: 0.8281 - val_loss: 0.3670 - val_accuracy: 0.8750
# Epoch 52/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4663 - accuracy: 0.8750 - val_loss: 0.3884 - val_accuracy: 0.8750
# Epoch 53/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4648 - accuracy: 0.8594 - val_loss: 0.3946 - val_accuracy: 0.8750
# Epoch 54/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4760 - accuracy: 0.8438 - val_loss: 0.3782 - val_accuracy: 0.8750
# Epoch 55/90
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4323 - accuracy: 0.8906 - val_loss: 0.3715 - val_accuracy: 0.8750
# Epoch 56/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4404 - accuracy: 0.8750 - val_loss: 0.3739 - val_accuracy: 0.8750
# Epoch 57/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4313 - accuracy: 0.8750 - val_loss: 0.3701 - val_accuracy: 0.8750
# Epoch 58/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4028 - accuracy: 0.9375 - val_loss: 0.3563 - val_accuracy: 0.8750
# Epoch 59/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3944 - accuracy: 0.8906 - val_loss: 0.3627 - val_accuracy: 0.8750
# Epoch 60/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4034 - accuracy: 0.9219 - val_loss: 0.3659 - val_accuracy: 0.8750
# Epoch 61/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4214 - accuracy: 0.9375 - val_loss: 0.3547 - val_accuracy: 0.8750
# Epoch 62/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4161 - accuracy: 0.9219 - val_loss: 0.3480 - val_accuracy: 0.8750
# Epoch 63/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4296 - accuracy: 0.8750 - val_loss: 0.3528 - val_accuracy: 0.9375
# Epoch 64/90
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4318 - accuracy: 0.8906 - val_loss: 0.3409 - val_accuracy: 0.9375
# Epoch 65/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4182 - accuracy: 0.8750 - val_loss: 0.3308 - val_accuracy: 0.8750
# Epoch 66/90
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3825 - accuracy: 0.9375 - val_loss: 0.3241 - val_accuracy: 0.8750
# Epoch 67/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3944 - accuracy: 0.9062 - val_loss: 0.3211 - val_accuracy: 0.8750
# Epoch 68/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3931 - accuracy: 0.9375 - val_loss: 0.3228 - val_accuracy: 0.9375
# Epoch 69/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3789 - accuracy: 0.9219 - val_loss: 0.3136 - val_accuracy: 0.9375
# Epoch 70/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4041 - accuracy: 0.8750 - val_loss: 0.3085 - val_accuracy: 0.8750
# Epoch 71/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3564 - accuracy: 0.9688 - val_loss: 0.3077 - val_accuracy: 0.9375
# Epoch 72/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3487 - accuracy: 0.9531 - val_loss: 0.3091 - val_accuracy: 0.8750
# Epoch 73/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3421 - accuracy: 0.9531 - val_loss: 0.3112 - val_accuracy: 0.8750
# Epoch 74/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3598 - accuracy: 0.9375 - val_loss: 0.3129 - val_accuracy: 0.9375
# Epoch 75/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3724 - accuracy: 0.9375 - val_loss: 0.3065 - val_accuracy: 0.9375
# Epoch 76/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3792 - accuracy: 0.9062 - val_loss: 0.3070 - val_accuracy: 0.8750
# Epoch 77/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3508 - accuracy: 0.9375 - val_loss: 0.3064 - val_accuracy: 0.8750
# Epoch 78/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4033 - accuracy: 0.8906 - val_loss: 0.3166 - val_accuracy: 0.9375
# Epoch 79/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3442 - accuracy: 0.9531 - val_loss: 0.3074 - val_accuracy: 0.9375
# Epoch 80/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3440 - accuracy: 0.9531 - val_loss: 0.3083 - val_accuracy: 0.8750
# Epoch 81/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3290 - accuracy: 0.9375 - val_loss: 0.3087 - val_accuracy: 0.8750
# Epoch 82/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3494 - accuracy: 0.9219 - val_loss: 0.3023 - val_accuracy: 0.8750
# Epoch 83/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3371 - accuracy: 0.9219 - val_loss: 0.3010 - val_accuracy: 0.8750
# Epoch 84/90
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3337 - accuracy: 0.9531 - val_loss: 0.3032 - val_accuracy: 0.8750
# Epoch 85/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3578 - accuracy: 0.9219 - val_loss: 0.3067 - val_accuracy: 0.8750
# Epoch 86/90
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3534 - accuracy: 0.9062 - val_loss: 0.2991 - val_accuracy: 0.8750
# Epoch 87/90
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3351 - accuracy: 0.9531 - val_loss: 0.2934 - val_accuracy: 0.8750
# Epoch 88/90
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3259 - accuracy: 0.9844 - val_loss: 0.3174 - val_accuracy: 0.8750
# Epoch 89/90
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3306 - accuracy: 0.9219 - val_loss: 0.3084 - val_accuracy: 0.8750
# Epoch 90/90
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3178 - accuracy: 0.9844 - val_loss: 0.3117 - val_accuracy: 0.8750

# %%
model.get_weights()
# Out:
# [array([[ 0.75681627,  0.1962367 ,  1.1435041 , -1.8974744 , -0.9415289 ,
#          -1.201596  ,  1.3668759 ,  0.33078423,  0.20545791],
#         [ 0.7082838 , -1.1517526 ,  0.6109304 , -1.489513  ,  1.2821805 ,
#           0.74898165,  0.6332057 , -1.6688114 , -0.88174933]],
#        dtype=float32),
#  array([ 0.1634242 , -0.07917589,  0.00198994, -0.07072709, -0.14772575,
#         -0.02048441, -0.03271218,  0.08898691, -0.1063096 ], dtype=float32),
#  array([[-3.9789310e-01,  7.2533441e-01, -2.4917775e-01, -1.3657261e-01,
#          -4.4343817e-01,  3.5587093e-01,  7.2786176e-01, -2.7088001e-02],
#         [-2.3997147e-03, -6.3289660e-01,  6.7747432e-01,  2.0649834e-01,
#          -4.0713403e-01, -2.7333310e-01, -2.1728010e-01,  5.5116791e-01],
#         [-3.7254018e-01,  3.3474824e-01,  1.4709371e-02,  4.5055169e-01,
#           3.8885719e-01, -4.2056072e-01, -2.6463923e-01,  4.6576613e-01],
#         [ 6.0241753e-01,  6.5883845e-01, -2.1700408e-01, -4.6375445e-01,
#          -2.0196961e-01,  9.7031686e-03, -4.9492228e-01, -2.1179864e-01],
#         [ 4.7822827e-01, -7.7921426e-01,  4.5723379e-01, -3.1225613e-01,
#           4.8434323e-01,  7.5588089e-01, -8.5566843e-01,  6.9949734e-01],
#         [-3.9756086e-02,  4.0833780e-04, -6.4195627e-01,  6.2557036e-01,
#           3.1086737e-01, -4.1142893e-01, -4.4814178e-01, -6.7154241e-01],
#         [ 4.0503925e-01, -1.1539601e-01,  5.6998231e-02,  9.4747013e-01,
#           5.2146035e-01, -9.4244039e-01,  7.0720814e-02, -4.8255104e-01],
#         [-5.3308541e-01,  3.4041286e-01,  2.4077357e-03, -5.2291013e-02,
#          -6.5411478e-01,  3.0873442e-01, -2.8615144e-01,  8.3424991e-01],
#         [ 6.7811817e-01, -2.2543176e-01,  8.2183756e-02,  4.3892510e-02,
#          -6.2981445e-01,  4.2599669e-01, -2.8004456e-01,  8.8076520e-01]],
#        dtype=float32),
#  array([-0.18726249,  0.0217675 , -0.12152243, -0.07378068, -0.16733472,
#         -0.00331013,  0.20778857, -0.02772982], dtype=float32),
#  array([[-0.618586  , -0.5567762 , -0.32901925, -0.76971865,  0.6360927 ,
#           0.37144393,  0.68487346],
#         [ 0.02894419, -0.3525523 , -0.03512911,  0.7252624 ,  0.39325282,
#          -0.33595365,  0.24859372],
#         [-0.14253241, -0.72041917,  0.4500228 ,  0.09255187,  0.11792024,
#           0.36271608,  0.42132267],
#         [-0.3899862 , -0.02893219,  0.88669455,  0.09320714,  0.42682654,
#           0.21367171,  0.7892295 ],
#         [-0.780011  ,  0.99165547,  0.17948045, -0.31538293,  0.3795307 ,
#          -0.00389069,  0.6682341 ],
#         [ 0.78774863, -0.4587624 ,  0.4330075 ,  0.80693   ,  0.28062966,
#          -0.66932535, -0.12033083],
#         [-0.21094179,  0.01274338,  0.2759661 ,  0.21632206, -0.80324894,
#          -0.37426132, -0.44199643],
#         [ 0.34603724,  0.18983547,  0.4679247 , -0.01238907,  0.13899757,
#           0.10556849,  0.6482468 ]], dtype=float32),
#  array([ 0.03487191, -0.07667919, -0.01592877,  0.17377779, -0.12917182,
#          0.1037886 , -0.1759329 ], dtype=float32),
#  array([[-0.82606506,  0.92522913,  0.5637063 ,  0.340665  , -0.3167742 ,
#          -0.21101089],
#         [-0.27879584,  0.39271447, -0.6747394 ,  1.0189347 ,  0.29260534,
#           0.26372838],
#         [ 0.29481754,  0.7802166 ,  0.70983267,  0.64756864,  0.66201544,
#           0.65106696],
#         [ 0.3362007 , -0.31307846,  0.78840125, -0.1021698 , -0.60576826,
#           0.31212848],
#         [ 0.22547896, -0.09862193,  0.15755962,  0.72030634, -0.24556561,
#          -0.66351545],
#         [-0.8484282 , -0.7393524 , -0.77587175, -0.33607554,  0.09320202,
#           0.47669476],
#         [-0.33155027, -0.04447723, -0.29903206,  0.563103  , -0.5764532 ,
#          -0.7175069 ]], dtype=float32),
#  array([ 0.1604533 ,  0.03375313,  0.13608305, -0.15638167, -0.00933695,
#         -0.0554572 ], dtype=float32),
#  array([[-0.44670486, -0.5480052 ,  0.6588607 ,  0.0630641 ,  0.85124826,
#          -0.17221007],
#         [ 0.1370647 ,  0.2413641 , -0.8102355 , -0.7411585 , -0.04618362,
#          -0.50740767],
#         [-0.4957285 , -0.26865777, -0.0324982 , -0.04427338,  0.48763892,
#          -0.36398557],
#         [-0.41934848,  0.04313799,  0.28248698, -0.08583045, -0.7300399 ,
#           0.8165507 ],
#         [-0.39713   , -0.01156823,  0.63756096, -0.40524364, -0.08609366,
#          -0.11316606],
#         [ 0.9192164 ,  0.17441219, -0.35298836, -0.6649966 ,  0.00232907,
#          -0.630727  ]], dtype=float32),
#  array([ 0.        , -0.01028967,  0.13965812,  0.        , -0.05540913,
#         -0.15770608], dtype=float32),
#  array([[ 0.55018926,  0.11393976,  0.23965359, -0.6841178 , -0.53451824],
#         [-0.64700854,  1.2139407 ,  0.3457341 ,  0.52485025, -0.5859654 ],
#         [-0.66506636, -0.46062756, -0.03064966, -0.03352115,  0.4681701 ],
#         [ 0.99916863,  0.69081044,  0.8694091 ,  0.6908219 ,  0.8415463 ],
#         [ 0.4986107 , -0.8162441 , -0.84366506,  0.5746148 ,  0.24839911],
#         [ 0.98123574,  0.48744845, -0.6773455 ,  0.9521463 , -0.9953524 ]],
#        dtype=float32),
#  array([-0.09350958, -0.15674022,  0.02331783, -0.22243811, -0.00167677],
#        dtype=float32),
#  array([[-1.0781975 , -0.5365939 ,  1.2400603 ,  0.1938415 ,  0.80644184],
#         [-0.68534184, -0.296426  ,  0.39470664, -0.4041981 ,  0.18704082],
#         [ 0.513474  ,  0.01898089,  0.31541225, -0.37872112, -1.06137   ],
#         [ 0.31460047, -0.735138  ,  0.212695  , -0.14156185, -0.89706284],
#         [-0.7720393 , -0.7170365 , -0.2565345 , -1.0645211 ,  0.11589491]],
#        dtype=float32),
#  array([-0.00387397, -0.01641907, -0.11854112,  0.17459054, -0.00235606],
#        dtype=float32),
#  array([[-0.8094308 ,  0.4590104 ,  0.06470726, -0.12884754],
#         [ 0.64564264,  0.87725604, -0.8892359 , -0.54552925],
#         [ 0.53955853,  0.7317977 , -0.38504744, -0.63986284],
#         [-1.2632285 , -1.2299883 ,  0.3624416 , -1.0751004 ],
#         [-0.7156168 ,  0.87517273,  0.49499533, -0.811391  ]],
#        dtype=float32),
#  array([-0.02102535, -0.10762433, -0.03998908,  0.        ], dtype=float32),
#  array([[ 1.1749356 ,  1.0732892 ],
#         [ 0.11246018,  1.235137  ],
#         [-0.08889956,  0.90178716],
#         [ 0.08338928,  1.0515033 ]], dtype=float32),
#  array([-0.0023869 , -0.04541659], dtype=float32),
#  array([[-1.0487268],
#         [-1.4536915]], dtype=float32),
#  array([0.3985273], dtype=float32)]

# %%
y_cap=model.predict(X_tests)
# Out:
# 1/1 [==============================] - 0s 111ms/step

# %%
y_capf=np.where(y_cap>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_capf)
# Out:
# 0.7

# %%
data = np.array([history.history["loss"],history.history["val_loss"]])
# data = data.reshape(50,2)
[[data[:,0].max(),data[:,1].max()]]
# Out:
# [[0.6902496814727783, 0.6870784759521484]]

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.show()

# %%
plt.figure(figsize=(8,6),dpi=150)
plt.plot(history.history["loss"],'black',linewidth=5)
plt.plot(history.history["val_loss"],'r--',linewidth=5)
plt.table(cellText=[[data[:,0].max(),data[:,1].max()],["Min Train Loss","Min Validation Loss"],[data[:,0].min(),data[:,1].min()]],cellLoc='center',colWidths=[0.4,0.4,0.4],
         colLabels=['Max Train Loss','Max Validation Loss'],colColours=['pink','yellow'],bbox=[0,0,1,1])
plt.legend(["Loss","Val_Loss"])
plt.title("Train Loss and Validation Loss",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("Number of Epochs",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("Loss",color='red',fontsize='medium',fontfamily='serif')
plt.show()

# %%
from mlxtend.plotting import plot_decision_regions as pt

plt.figure(figsize=(8,6))
pt(X_trains,y_train.values.astype(int),clf=model)
plt.title("X_train Decision regions",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("X_train",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("y_train",color='red',fontsize='medium',fontfamily='serif')
plt.show()
# Out:
# 15000/15000 [==============================] - 23s 2ms/step

# %%
y_pred = model.predict(X_tests)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
y_predf = np.array([1 if x>0.5 else 0 for x in y_pred])

# %%
plt.figure(figsize=(8,6))
pt(X_tests,y_predf.astype(int),clf=model)
plt.title("X_test Decision regions",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("X_test",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("y_test",color='red',fontsize='medium',fontfamily='serif')
plt.show()
# Out:
#  7305/15000 [=============>................] - ETA: 11s
