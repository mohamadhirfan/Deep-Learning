# %% [markdown]
# <div style="color:white;background-color:black;border:5px solid powderblue;border-radius:25px;text-align:center;font-family:Copperplate">
#     <h1>DATA DECISION PATHS</h1><hr style="border:2px solid powderblue">
#     <div style="color:white;background-color:black;border-radius:25px;text-align:right;">
#         <br>
#         <h2 style="color:red;display:inline;">NAME:</h2><h2 style="display:inline;">Mohamadh Irfan</h2><br>
#         <h2 style="color:red;display:inline;">BATCH:</h2><h2 style="display:inline;padding-right:62px;">AI-ELITE-7</h2>
#     </div>
#     <div style="color:white;background-color:black;border-radius:25px;text-align:Left;font-family:Courier New;margin-left:4%;">
#         <h3 style="color:white;font-weight:bold;font-family:Papyrus">Data Description:</h3>
#         <p style="padding-left:8%;padding-right:8%;">
#         - The dataset consists of three columns and 100 rows which includes two feature columns and one label column.<br>
#         - Features columns are in the form of float and continuous values ranges from <strong>[-1.318500	 to 2.181372	]</strong> and <strong>[-1.035702 to 1.571899 ]</strong> and the means are at <strong>[0.500420	and 0.228701]</strong>.<br>
#          - Whereas label is in the form discreate numerical integer values that inclueds <strong>[0 and 1]</strong>. 50% of the data consists of 0 and rest consists of 1 as labels.<br>
#             - There are zero duplicates and no null values consists in the dataset.<br>
#             <strong>-</strong> Pattern that is formed by the input features is <strong>u shape</strong>. That means some datapoints are ushaped and some datapoints inverted u shape.
#             <img src=https://cdn.discordapp.com/attachments/1060498631981023282/1109938065637658705/image.png
#                  >
#         </p>
#         <br>
#     </div>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("1.ushape.csv",header=None)

# %%
df.head()
# Out:
#           0         1    2
# 0  0.031595  0.986988  0.0
# 1  2.115098 -0.046244  1.0
# 2  0.882490 -0.075756  0.0
# 3 -0.055144 -0.037332  1.0
# 4  0.829545 -0.539321  1.0

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# 0    0
# 1    0
# 2    0
# dtype: int64

# %%
num=df.select_dtypes(include='number')

# %%
for i in num:
    sns.boxplot(num[i])
    plt.show()

# %%
df.describe()
# Out:
#                 0           1           2
# count  100.000000  100.000000  100.000000
# mean     0.500420    0.228701    0.500000
# std      0.891044    0.592885    0.502519
# min     -1.318500   -1.035702    0.000000
# 25%     -0.140330   -0.203260    0.000000
# 50%      0.470678    0.188660    0.500000
# 75%      1.112008    0.658448    1.000000
# max      2.181372    1.571899    1.000000

# %%
df[2].value_counts()
# Out:
# 0.0    50
# 1.0    50
# Name: 2, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[[0,1]],df[2],test_size=0.1,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((90, 2), (10, 2))

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_trains = scale.fit_transform(X_train)
X_tests = scale.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
model = Sequential()
model.add(Dense(14,activation="relu",kernel_initializer="he_uniform",input_dim=2))

model.add(Dense(13,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(12,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(10,activation="relu",kernel_initializer="he_uniform"))



model.add(Dense(10,activation="relu",kernel_initializer="he_uniform"))




model.add(Dense(8,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(6,activation="relu",kernel_initializer="he_uniform"))


model.add(Dense(4,activation="relu",kernel_initializer="he_uniform"))

model.add(Dense(3,activation="relu",kernel_initializer="he_uniform"))
model.add(Dropout(0.1))
model.add(Dense(2,activation="relu",kernel_initializer="he_uniform"))
model.add(Dropout(0.1))


model.add(Dense(1,activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_57"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_710 (Dense)           (None, 14)                42
#
#  dense_711 (Dense)           (None, 13)                195
#
#  dense_712 (Dense)           (None, 12)                168
#
#  dense_713 (Dense)           (None, 10)                130
#
#  dense_714 (Dense)           (None, 10)                110
#
#  dense_715 (Dense)           (None, 8)                 88
#
#  dense_716 (Dense)           (None, 6)                 54
#
#  dense_717 (Dense)           (None, 4)                 28
#
#  dense_718 (Dense)           (None, 3)                 15
#
#  dropout_295 (Dropout)       (None, 3)                 0
#
#  dense_719 (Dense)           (None, 2)                 8
#
#  dropout_296 (Dropout)       (None, 2)                 0
#
#  dense_720 (Dense)           (None, 1)                 3
#
# =================================================================
# Total params: 841
# Trainable params: 841
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
history = model.fit(X_trains,y_train,epochs=55,batch_size=10,validation_split=0.1)
# Out:
# Epoch 1/55
# 9/9 [==============================] - 3s 37ms/step - loss: 0.7206 - accuracy: 0.4691 - val_loss: 0.6861 - val_accuracy: 0.6667
# Epoch 2/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6895 - accuracy: 0.4321 - val_loss: 0.6763 - val_accuracy: 0.6667
# Epoch 3/55
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6707 - accuracy: 0.6296 - val_loss: 0.6603 - val_accuracy: 0.7778
# Epoch 4/55
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6549 - accuracy: 0.6420 - val_loss: 0.6380 - val_accuracy: 0.8889
# Epoch 5/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6386 - accuracy: 0.6790 - val_loss: 0.5992 - val_accuracy: 0.8889
# Epoch 6/55
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6145 - accuracy: 0.7531 - val_loss: 0.5517 - val_accuracy: 0.7778
# Epoch 7/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5979 - accuracy: 0.7407 - val_loss: 0.5055 - val_accuracy: 0.7778
# Epoch 8/55
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5973 - accuracy: 0.6914 - val_loss: 0.4668 - val_accuracy: 0.7778
# Epoch 9/55
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5792 - accuracy: 0.7901 - val_loss: 0.4419 - val_accuracy: 0.7778
# Epoch 10/55
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5766 - accuracy: 0.7654 - val_loss: 0.4283 - val_accuracy: 0.7778
# Epoch 11/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5533 - accuracy: 0.8148 - val_loss: 0.4195 - val_accuracy: 0.7778
# Epoch 12/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5527 - accuracy: 0.7901 - val_loss: 0.4117 - val_accuracy: 0.7778
# Epoch 13/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5290 - accuracy: 0.8395 - val_loss: 0.4065 - val_accuracy: 0.7778
# Epoch 14/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5244 - accuracy: 0.8272 - val_loss: 0.4064 - val_accuracy: 0.7778
# Epoch 15/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5559 - accuracy: 0.7901 - val_loss: 0.4065 - val_accuracy: 0.8889
# Epoch 16/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5304 - accuracy: 0.8148 - val_loss: 0.4029 - val_accuracy: 0.8889
# Epoch 17/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5646 - accuracy: 0.7407 - val_loss: 0.3955 - val_accuracy: 0.8889
# Epoch 18/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5148 - accuracy: 0.8519 - val_loss: 0.3925 - val_accuracy: 0.8889
# Epoch 19/55
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5167 - accuracy: 0.8148 - val_loss: 0.3935 - val_accuracy: 0.8889
# Epoch 20/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5231 - accuracy: 0.7901 - val_loss: 0.3917 - val_accuracy: 0.8889
# Epoch 21/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5305 - accuracy: 0.7778 - val_loss: 0.3911 - val_accuracy: 0.8889
# Epoch 22/55
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5049 - accuracy: 0.8395 - val_loss: 0.3894 - val_accuracy: 0.8889
# Epoch 23/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5446 - accuracy: 0.7654 - val_loss: 0.3938 - val_accuracy: 0.8889
# Epoch 24/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4993 - accuracy: 0.8272 - val_loss: 0.3953 - val_accuracy: 0.8889
# Epoch 25/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5012 - accuracy: 0.8395 - val_loss: 0.4019 - val_accuracy: 0.8889
# Epoch 26/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5164 - accuracy: 0.7901 - val_loss: 0.4099 - val_accuracy: 0.8889
# Epoch 27/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4640 - accuracy: 0.8519 - val_loss: 0.4107 - val_accuracy: 0.8889
# Epoch 28/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5286 - accuracy: 0.7531 - val_loss: 0.4073 - val_accuracy: 0.8889
# Epoch 29/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5066 - accuracy: 0.8148 - val_loss: 0.4053 - val_accuracy: 0.8889
# Epoch 30/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4860 - accuracy: 0.8148 - val_loss: 0.4023 - val_accuracy: 0.8889
# Epoch 31/55
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4890 - accuracy: 0.8148 - val_loss: 0.3945 - val_accuracy: 0.8889
# Epoch 32/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4755 - accuracy: 0.8395 - val_loss: 0.3970 - val_accuracy: 0.8889
# Epoch 33/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4648 - accuracy: 0.8395 - val_loss: 0.3931 - val_accuracy: 0.8889
# Epoch 34/55
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4825 - accuracy: 0.8148 - val_loss: 0.3894 - val_accuracy: 0.8889
# Epoch 35/55
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4676 - accuracy: 0.8395 - val_loss: 0.3850 - val_accuracy: 0.8889
# Epoch 36/55
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4572 - accuracy: 0.8395 - val_loss: 0.3807 - val_accuracy: 0.8889
# Epoch 37/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4544 - accuracy: 0.8519 - val_loss: 0.3772 - val_accuracy: 0.8889
# Epoch 38/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4886 - accuracy: 0.8025 - val_loss: 0.3736 - val_accuracy: 0.8889
# Epoch 39/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4680 - accuracy: 0.8272 - val_loss: 0.3684 - val_accuracy: 0.8889
# Epoch 40/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4722 - accuracy: 0.8272 - val_loss: 0.3657 - val_accuracy: 0.8889
# Epoch 41/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4446 - accuracy: 0.8519 - val_loss: 0.3616 - val_accuracy: 0.8889
# Epoch 42/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4433 - accuracy: 0.8642 - val_loss: 0.3578 - val_accuracy: 0.8889
# Epoch 43/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4379 - accuracy: 0.8519 - val_loss: 0.3552 - val_accuracy: 0.8889
# Epoch 44/55
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4317 - accuracy: 0.8642 - val_loss: 0.3579 - val_accuracy: 0.8889
# Epoch 45/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4194 - accuracy: 0.8765 - val_loss: 0.3577 - val_accuracy: 0.8889
# Epoch 46/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4341 - accuracy: 0.8519 - val_loss: 0.3547 - val_accuracy: 0.8889
# Epoch 47/55
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4233 - accuracy: 0.8765 - val_loss: 0.3521 - val_accuracy: 0.8889
# Epoch 48/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3971 - accuracy: 0.8889 - val_loss: 0.3511 - val_accuracy: 0.8889
# Epoch 49/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4351 - accuracy: 0.8519 - val_loss: 0.3570 - val_accuracy: 0.8889
# Epoch 50/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4220 - accuracy: 0.8519 - val_loss: 0.3555 - val_accuracy: 0.8889
# Epoch 51/55
# 9/9 [==============================] - 0s 9ms/step - loss: 0.
#         [ 0.546157  ,  0.44945756, -0.6110118 ,  0.20192659, -0.45458877,
#          -0.5864119 ,  0.30658945,  0.5508461 ,  0.6571133 , -0.64129525,
#           0.33458948,  0.2928136 ],
#         [ 0.06956941,  0.51151854, -0.31241715, -0.4764972 , -0.6759536 ,
#           0.20557988, -0.25883353, -0.15589021, -0.01483309, -0.31881794,
#           0.05552161, -0.08848902],
#         [ 0.65577424, -0.42721432, -0.23787022,  0.519443  ,  0.5692758 ,
#          -0.00370723, -0.03403695,  0.6676059 , -0.30855843, -0.37126583,
#          -0.04396662, -0.37854066],
#         [-0.24392779,  0.21297821, -0.5216156 ,  0.23772335,  0.6293028 ,
#          -0.05897427,  0.06330152,  0.5580849 ,  0.5930672 ,  0.60753834,
#           0.60869986,  0.6167107 ],
#         [-0.2096492 ,  0.39570674, -0.6622444 ,  0.32751414,  0.01443005,
#          -0.42314646, -0.43935078, -0.39446253,  0.56263053,  0.11805066,
#           0.18186392, -0.59204787],
#         [-0.41413945, -0.00851488,  0.14770138, -0.5446098 , -0.4476373 ,
#           0.6597239 ,  0.250592  , -0.13522135, -0.04097597, -0.22117741,
#           0.50555104, -0.16967428],
#         [ 0.5311483 , -0.23034853, -0.36577323, -0.10239746, -0.18038586,
#          -0.3937021 , -0.45950228, -0.07215492,  0.29078656, -0.49018884,
#           0.57408994, -0.67303884],
#         [-0.5823277 ,  0.49388206,  0.7210631 ,  0.31068468,  0.31498638,
#          -0.242861  ,  0.32892823, -0.17878565,  0.3459737 ,  0.15813491,
#           0.6385884 ,  0.17814602],
#         [-0.09761548,  0.06152987, -0.03648359,  0.17181168, -0.3721188 ,
#          -0.48610815, -0.01945645, -0.37138137,  0.4198672 ,  0.3294768 ,
#           0.5109566 , -0.0059251 ],
#         [-0.1982208 , -0.2567812 ,  0.6375334 , -0.43959308, -0.10635334,
#          -0.37018824,  0.62780017, -0.30222255, -0.5427206 ,  0.5565127 ,
#           0.5514019 ,  0.00599778],
#         [ 0.5514555 , -0.19129774, -0.01608365, -0.25919497, -0.4460918 ,
#          -0.62981963, -0.01701304, -0.18767816,  0.10615269,  0.5404403 ,
#          -0.27998185,  0.42270753]], dtype=float32),
#  array([ 0.01949368,  0.10890103,  0.05770462, -0.04197076, -0.07257095,
#          0.        ,  0.19427909, -0.04233646, -0.07180072, -0.03188136,
#         -0.07401965,  0.15706751], dtype=float32),
#  array([[-0.02852684, -0.04658759, -0.28620315,  0.05770907, -0.59270096,
#           0.39258754, -0.7448164 , -0.03599913,  0.41990066, -0.53473365],
#         [-0.49072957,  0.08197739, -0.33144942,  0.00954184,  0.36652568,
#           0.2471483 ,  0.7702406 ,  0.15386733, -0.71420485,  0.08227935],
#         [-0.5105275 ,  0.6547921 , -0.11213326, -0.11509036,  0.66154253,
#           0.6454838 ,  0.2523897 , -0.6022589 , -0.28463367, -0.66851884],
#         [ 0.30122322,  0.2099061 , -0.2897868 ,  0.67290294,  0.5580815 ,
#         [ 0.48863608, -0.51264167,  0.2633217 ,  0.80768377,  0.66475856,
#          -0.60861975],
#         [-0.29903913,  0.5388744 , -0.08024325, -0.7030072 ,  0.63929427,
#           0.8128141 ]], dtype=float32),
#  array([ 0.        , -0.06261222,  0.03943339,  0.        , -0.07695117,
#         -0.00702365], dtype=float32),
#  array([[-0.96970916, -0.7667532 ,  0.22503161, -0.3959279 ],
#         [-0.7409467 , -0.591319  ,  0.28602806,  0.80398774],
#         [-0.8966777 , -0.8120644 , -0.19276938, -0.16083051],
#         [-0.88678384,  0.64156747, -0.79632115,  0.3784225 ],
#         [ 0.35216045,  0.36446142,  1.0045205 ,  0.762895  ],
#         [ 0.48049974, -0.91011167,  0.05361409,  0.01778271]],
#        dtype=float32),
#  array([-0.02204668, -0.0139129 , -0.09393442, -0.05751087], dtype=float32),
#  array([[-1.1024808 ,  0.04170392,  0.68533087],
#         [ 0.33875388, -0.6146366 , -0.5575678 ],
#         [ 1.0322229 ,  0.4654722 , -0.27601632],
#         [-0.66311675,  0.53641   , -0.53813124]], dtype=float32),
#  array([-0.01516096, -0.06737079, -0.00305099], dtype=float32),
#  array([[-0.34904984,  0.27645794],
#         [ 0.93703437, -0.16682127],
#         [ 1.3846674 , -0.43141255]], dtype=float32),
#  array([-0.06452506, -0.00430862], dtype=float32),
#  array([[-1.2549996],
#         [-0.7488529]], dtype=float32),
#  array([0.33994812], dtype=float32)]

# %%
y_cap=model.predict(X_tests)
# Out:
# 1/1 [==============================] - 0s 132ms/step

# %%
y_capf=np.where(y_cap>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_capf)
# Out:
# 0.9

# %%
data = np.array([history.history["loss"],history.history["val_loss"]])
# data = data.reshape(50,2)
[[data[:,0].max(),data[:,1].max()]]
# Out:
# [[0.72055983543396, 0.6894991397857666]]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.show()

# %%
plt.figure(figsize=(8,6),dpi=150)
plt.plot(history.history["loss"],'black',linewidth=5)
plt.plot(history.history["val_loss"],'r--',linewidth=5)
plt.table(cellText=[[data[:,0].max(),data[:,1].max()],["Min Train Loss","Min Validation Loss"],[data[:,0].min(),data[:,1].min()]],cellLoc='center',colWidths=[0.4,0.4,0.4],
         colLabels=['Max Train Loss','Max Validation Loss'],colColours=['pink','yellow'],bbox=[0,0,1,1])
plt.legend(["Loss","Val_Loss"])
plt.title("Train Loss and Validation Loss",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("Number of Epochs",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("Loss",color='red',fontsize='medium',fontfamily='serif')
plt.show()

# %%
from mlxtend.plotting import plot_decision_regions as pt

# %%
plt.figure(figsize=(8,6))
pt(X_trains,y_train.values.astype(int),clf=model)
plt.title("X_train Decision regions",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("X_train",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("y_train",color='red',fontsize='medium',fontfamily='serif')
plt.show()
# Out:
# 15000/15000 [==============================] - 18s 1ms/step

# %%
y_pred = model.predict(X_tests)
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
y_predf = np.array([1 if x>0.5 else 0 for x in y_pred])

# %%
plt.figure(figsize=(8,6))
pt(X_tests,y_predf.astype(int),clf=model)
plt.title("X_test Decision regions",color='red',fontsize='medium',fontfamily='serif')
plt.xlabel("X_test",color='red',fontsize='medium',fontfamily='serif')
plt.ylabel("y_test",color='red',fontsize='medium',fontfamily='serif')
plt.show()
# Out:
# 15000/15000 [==============================] - 18s 1ms/step
